# %% [markdown]
# # Image Transformations Lab
# All  of  the  programming  assignments  are  to  be  done  in  Python  using  additional  libraries  specified  in  the  assignments.  There  are many  libraries  available,  some  of  which  we  will  be  using,  and  you  are  welcome  to  use  them  with  one  exception:  if  the  library  or  a  function  within  it  performs  the  specific  function  you  are  asked  to  code,  you  may  not  use  that  other  than  perhaps  as  a  reference  to  compare  against. All  of  the  code  you  submit  must  be  your  own. You are welcome to turn in a completed jupyter notebook.
#
# The following code will load an image you can use for this lab. If needed make sure to install PIL using *pip install PIL* or *conda install PIL*.
#
# **Note:** On the homework, the direction of the positve Y-axis was up. In this lab (and most image packages), the direction of the positive Y-axis is down. This means that you will need to rotate in the opposite direction of what you did on the homework.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import math


# %matplotlib notebook

def compose(frame, image, transformation):
    
    width, height = frame.size
    
    #Invert matrix for compose function, grab values for Affine Transform
    t = np.linalg.inv(transformation)
    a=t[0,0]; b=t[0,1]; c=t[0,2]; d=t[1,0]; e=t[1,1]; f=t[1,2]
    
    image = image.transform((width,height), Image.AFFINE,(a,b,c,d,e,f), Image.BICUBIC)

    #Make mask from image's location
    im = np.sum(np.asarray(image), -1)
    vals = 255.0*( im > 0)
    mask = Image.fromarray(vals).convert("1")

    #Composite images together
    result = Image.composite(image,frame,mask)

    return result


#Open the two images
filename = "PictureFrameCollage.png"
frame = Image.open(filename).convert("RGB")

filename0 = "Bird0.png"
im = Image.open(filename0).convert("RGB")

#Define the transformation to the first picture frame
transformation = np.matrix([[1,0,619],[0,1,433],[0,0,1]])

#Compose the two images together
result_frame = compose(frame, im, transformation)
    
# #Show the result
# plt.imshow(result_frame)
# plt.show()

#Uncomment this line if you want to save the image
#result.save("Output.png")
#Open the two images

#######################################################

filename0 = "Bird1.png"
im = Image.open(filename0).convert("RGB")

#Define the transformation to the first picture frame
transformation = np.matrix([[1.21,0,0], [0,1.21,0],[0,0,1]]) * np.matrix([[1,0,36],[0,1,27],[0,0,1]])
print(transformation.shape)
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird2.png"
im = Image.open(filename0).convert("RGB")

#Define the transformation to the first picture frame
transformation = np.matrix([[1,0,283],[0,1,46],[0,0,1]]) * np.matrix([[.389,0,0], [0,.389,0],[0,0,1]])
print(transformation.shape)
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird3.png"
im = Image.open(filename0).convert("RGB")

#Define the transformation to the first picture frame
transformation = np.matrix([[1,0,514],[0,1,225],[0,0,1]]) * np.matrix([[.389,0,0], [0,.389,0],[0,0,1]])
print(transformation.shape)
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird4.png"
im = Image.open(filename0).convert("RGB")

#Define the transformation to the first picture frame
transformation = np.matrix([[1,0,308],[0,1,463],[0,0,1]]) * np.matrix([[.736,0,0], [0,.736,0],[0,0,1]])
print(transformation.shape)
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird5.png"
im = Image.open(filename0).convert("RGB")

#Scale
scale = np.matrix([[1.21,0,0], [0,1.21,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/12), math.sin(math.pi/12), 0],
                    [-math.sin(math.pi/12), math.cos(math.pi/12),0],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,46],[0,1,354],[0,0,1]])              

transformation = shift * scale * rotate
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird6.png"
im = Image.open(filename0).convert("RGB")

#Scale
scale = np.matrix([[.736,0,0], [0,.736,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/12), math.sin(math.pi/12), 0],
                    [-math.sin(math.pi/12), math.cos(math.pi/12),0],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,633],[0,1,228],[0,0,1]])              

transformation = shift * scale * rotate
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird7.png"
im = Image.open(filename0).convert("RGB")

#Scale
#scale = np.matrix([[.736,0,0], [0,.736,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/6), math.sin(math.pi/6), 0],
                    [-math.sin(math.pi/6), math.cos(math.pi/6),0],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,419],[0,1,87],[0,0,1]])              

transformation = shift * rotate
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird8.png"
im = Image.open(filename0).convert("RGB")

#Scale
#scale = np.matrix([[.736,0,0], [0,.736,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/4), math.sin(math.pi/4), 0],
                    [-math.sin(math.pi/4), math.cos(math.pi/4),0],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,385],[0,1,379],[0,0,1]])              

transformation = shift * rotate
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird9.png"
im = Image.open(filename0).convert("RGB")

#Scale
#scale = np.matrix([[.736,0,0], [0,.736,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/4), -math.sin(math.pi/4), 0],
                    [math.sin(math.pi/4), math.cos(math.pi/4),0],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,350],[0,1,138],[0,0,1]])              

transformation = shift * rotate
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird10.png"
im = Image.open(filename0).convert("RGB")

#Scale
scale = np.matrix([[.653,0,0], [0,.653,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/12), -math.sin(math.pi/12), 12],
                    [math.sin(math.pi/12), math.cos(math.pi/12),12],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,666],[0,1,30],[0,0,1]])              

transformation = shift * scale * rotate 
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#######################################################

filename0 = "Bird9.png"
im = Image.open(filename0).convert("RGB")

#Scale
scale = np.matrix([[.389,0,0], [0,.389,0],[0,0,1]])

#Rotate by pi/6
rotate = np.matrix([[math.cos(math.pi/4), -math.sin(math.pi/4), 0],
                    [math.sin(math.pi/4), math.cos(math.pi/4),0],
                    [0, 0, 1]])
#Translate 
shift = np.matrix([[1,0,305],[0,1,358],[0,0,1]])              

transformation = shift * scale * rotate
                  
#Compose the two images together
result_frame = compose(result_frame, im, transformation)

#Show the result
plt.imshow(result_frame)
plt.show()
# Out:
# (3, 3)
# (3, 3)
# (3, 3)
# (3, 3)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Tip: Make sure you are comfortable with building your own transformations and how the compositing code works, then try implementing your own general transform function.
